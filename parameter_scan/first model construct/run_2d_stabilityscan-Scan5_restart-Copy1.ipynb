# %% [raw]
# import os
# import multiprocessing as mp
#
# # 1. Prevent macOS from crashing when using 'fork' with NumPy/Accelerate
# os.environ['OBJC_DISABLE_INITIALIZE_FORK_SAFETY'] = 'YES'
#
# # 2. Force the start method for this Jupyter session
# try:
#     mp.set_start_method('fork', force=True)
#     print(f"Success! Start method set to: {mp.get_start_method()}")
# except RuntimeError as e:
#     print(f"Error: {e}")

# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Make model/ and parameter_scan/ importable
sys.path.insert(0, os.path.abspath('../../model'))
sys.path.insert(0, os.path.abspath('../.'))

from xso.parscans import run_xso_parscan,run_xso_stabilityscan

from cariaco_ssm_setup import model, model_setup, phyto_esd, zoo_esd
from cariaco_obs import load_cariaco_targets
from parscan_utils import (
    compute_cost_grid, find_best_fit, get_default_from_setup, extract_steady_state_seed,
)
from parscan_plots import (
    plot_cost_heatmap,
    plot_model_vs_obs_boxplots, summarize_best_fit,
)

# %%
REGIME = 'all'
obs_vec, labels, bin_defs, monthly_df, forcing = load_cariaco_targets(regime=REGIME)

print(f"Observation targets (regime='{REGIME}'):")
for lab, val in zip(labels, obs_vec):
    print(f"  {lab:20s}: {val:.5f}")
print(f"Months in filtered dataset: {len(monthly_df)}")
print(f"Regime forcing:")
print(f"  Inflow__FN = {forcing['Inflow__FN']:.4f}  mmol N m-2 d-1")
print(f"  Inflow__de = {forcing['Inflow__de']:.2f}  m")
print(f"  (F_N/d_e   = {forcing['Inflow__FN']/forcing['Inflow__de']:.6f}  mmol N m-3 d-1)")
# Out:
# Observation targets (regime='all'):
#   Pico (<2 µm)        : 0.25445
#   Nano (2-20 µm)      : 0.14510
#   Micro (>20 µm)      : 0.20366
#   Zoo >200 µm         : 0.06581
#   Zoo >500 µm         : 0.03743
#   NO3                 : 1.42750
#   PP                  : 0.32188
#   Export              : 2.71976
# Months in filtered dataset: 95
# Regime forcing:
#   Inflow__FN = 2.2251  mmol N m-2 d-1
#   Inflow__de = 47.02  m
#   (F_N/d_e   = 0.047319  mmol N m-3 d-1)

# %%
# from setup defaults d_e is 50.0; cariaco_obs.py forcing overrides this
# with the regime mean (~45.58). Pop FN since it's now the scan axis;
# keep d_e since we're not varying box geometry.
forcing.pop('Inflow__FN', None)

forcing['GGE__gge']                 = 0.17416  # Scan 1
forcing['GGE__f_egest_D']           = 0.55602  # Scan 2
forcing['DetritusRemin__k_remin']   = 0.07590  # Scan 2
forcing['PhytoMortality__f_mort_D'] = 0.47651  # Scan 4
# Grazing__KsZ NOT here — it's the scan axis

# %%
# Which parameters to scan, their ranges, and grid resolution
#
# FN × KsZ — productivity vs. grazing-pressure plane.
# - FN has never been varied in prior scans: it's been pinned to the
#   regime-mean from load_cariaco_targets ('all' regime ≈ 2.67). This
#   scan exposes the productivity axis. Range below brackets relaxed
#   and upwelling regime extremes with headroom; refine against
#   load_cariaco_targets(regime='upwelling' / 'relaxed') if desired.
# - KsZ ∈ [0.3, 10]: Hansen 1997 empirical range, Stock central 3.0.
#   Has pinned at 0.3 in every scan since the GGE refactor — this scan
#   tests whether higher FN unpins it.
P1_NAME   = 'Inflow__FN'
P1_LABEL  = 'New nutrient flux F_N (mmol N m⁻² d⁻¹)'
P1_VALUES = np.logspace(np.log10(0.5), np.log10(35.0), 30)
P2_NAME   = 'Grazing__KsZ'
P2_LABEL  = 'Zoo half-saturation K_sZ (mmol N m⁻³)'
P2_VALUES = np.logspace(np.log10(0.3), np.log10(10.0), 30)
# Scan runtime settings
N_PROCESSES = 20
AVG_WINDOW  = 1000   # days at tail of IVP to average for steady-state cost
print(f"2D scan: {P1_NAME} ({len(P1_VALUES)} pts)  x  {P2_NAME} ({len(P2_VALUES)} pts)")
print(f"Total runs: {len(P1_VALUES) * len(P2_VALUES)}")
print(f"  FN spans {P1_VALUES.min():.3f} – {P1_VALUES.max():.3f} mmol N m⁻² d⁻¹ "
      f"(log-spaced; brackets CARIACO regime extremes; "
      f"'all'-regime mean ≈ 2.67)")
print(f"  KsZ spans {P2_VALUES.min():.3f} – {P2_VALUES.max():.3f} mmol N m⁻³ "
      f"(log-spaced; Hansen 1997 empirical range, Stock central 3.0)")
# Out:
# 2D scan: Inflow__FN (30 pts)  x  Grazing__KsZ (30 pts)
# Total runs: 900
#   FN spans 0.500 – 35.000 mmol N m⁻² d⁻¹ (log-spaced; brackets CARIACO regime extremes; 'all'-regime mean ≈ 2.67)
#   KsZ spans 0.300 – 10.000 mmol N m⁻³ (log-spaced; Hansen 1997 empirical range, Stock central 3.0)

# %%
scan_results = run_xso_parscan(
    model_file_name='cariaco_ssm_setup',
    model_name='model',
    model_setup_name='model_setup_slim',
    param_name=P1_NAME,
    param_values=P1_VALUES,
    param_name2=P2_NAME,
    param_values2=P2_VALUES,
    processes=N_PROCESSES,
    fixed_overrides=forcing,
    postprocess_name='avg_tail',
    postprocess_kwargs={'avg_window': AVG_WINDOW},
)
# Out:
# PROGRESS: Completed 30/30 outer points. (Inflow__FN = 35.0).
#
# 2D Scan complete. Total Time taken: 744.10061 seconds.

# %%
seed_ds, iv_map = extract_steady_state_seed(scan_results, avg_window=AVG_WINDOW)


stability_results = run_xso_stabilityscan(
    model_file_name='cariaco_ssm_setup',
    model_name='model',
    model_setup_name='model_setup_stability',
    param_name=P1_NAME,
    param_values=P1_VALUES,
    param_name2=P2_NAME,
    param_values2=P2_VALUES,
    processes=N_PROCESSES,
    fixed_overrides=forcing,
    initial_values_ds=seed_ds,
    iv_mapping=iv_map,
)
# Out:
# PROGRESS: Completed 30/30 outer points. (Inflow__FN = 26.110783492250945).
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.9808e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 9.9747e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.7596e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.9223e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.4357e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.2598e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.3630e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3294e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.7370e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.1245e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3686e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.2929e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4367e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3227e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1746e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.7504e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.8448e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.6125e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1603e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1044e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.4722e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.2039e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.2040e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1982e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0379e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.2331e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.1394e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.0166e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.8129e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.9405e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.8665e-06
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.4645e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.2868e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.7163e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.4979e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3008e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.5965e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.6784e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.9936e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.9334e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.4242e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.3079e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.3140e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.6972e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.2959e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.8524e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.6388e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.2723e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1249e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.3764e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.8091e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0689e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.4943e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.4016e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.7733e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.6191e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3867e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.9208e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4787e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.6444e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.2816e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.6965e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.2886e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3220e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.7368e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.7353e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3724e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.3267e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.0117e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.6945e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.5778e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.7648e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.2078e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.4041e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.1427e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3466e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.2126e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0411e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.0889e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.6358e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.5785e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.1268e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.9286e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.0749e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.3858e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.2175e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3467e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.4093e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.9534e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.1923e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.7295e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1950e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.5520e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.1737e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.9176e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3306e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.0726e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.6372e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.4203e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.8726e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 9.9435e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.4038e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.3377e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.0450e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.7763e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.4593e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.4952e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.1096e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.0604e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.2794e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1436e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.7780e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.6712e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.6310e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.4781e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.3127e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.2662e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.4713e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.9986e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.3857e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.2679e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.5231e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.7917e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.4542e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.5377e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.1043e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 9.2523e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.0533e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.0667e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3308e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.0890e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.5649e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.0728e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.4541e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.0199e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.8297e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.3802e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.4106e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.2519e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.6005e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.2383e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0970e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.2582e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.0698e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.8158e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.4127e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.1447e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.3616e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.1832e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.8108e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.3920e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.3306e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.6584e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.1912e-06
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.8002e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.6628e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.6350e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.3192e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.7287e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.9856e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.7102e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.1638e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.1159e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.2542e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.5225e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.5731e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.7144e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.4013e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3185e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1885e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0285e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.2570e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.3960e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1671e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.2765e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.3044e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.5819e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.1962e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.0241e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0668e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.5430e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.7343e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.0082e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.4332e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.3644e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.6119e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.5397e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.5258e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 9.0660e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.6449e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3216e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.3765e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.9746e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.7183e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.1411e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.5960e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.2229e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.2868e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.3233e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.1520e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.8951e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1954e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0492e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.7278e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.4529e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.9359e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.7691e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.2120e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.8539e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.9437e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.4769e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 9.9097e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.1185e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 9.2321e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.9169e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.6993e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.8450e-06
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.6914e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.0808e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.2722e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.9470e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4603e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3527e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.2119e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0224e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.4707e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.1082e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.6812e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.3684e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.6322e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.4089e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.8704e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1567e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.2773e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.6928e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.1247e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.0164e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.0308e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.9177e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.7957e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.1292e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.1445e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.2141e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.2516e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.1763e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.2257e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.8854e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.7909e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.0860e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.9369e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.5628e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.7228e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.2996e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.4336e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.4855e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.7454e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.1703e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3863e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.6326e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.0630e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.1637e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.4039e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.9638e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1052e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.5045e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.6433e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.1667e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.5971e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.9701e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.2120e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.3391e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.1265e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.0170e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.1810e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.0441e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.7437e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.6906e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.4603e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.1100e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.2090e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.7656e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3112e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.0254e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.4113e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.3415e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.9940e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3272e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.6806e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.1805e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.2386e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.2263e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.7710e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1509e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0002e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.1890e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.8194e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.9844e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.9457e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.2120e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.7980e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.9525e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.0819e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.2113e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.2303e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.8129e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4304e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4435e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3339e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1892e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.8538e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.7069e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0670e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1597e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.3921e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.3462e-06
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.5053e-04
# ...
# [HOOK] Max eigenvalue real part: -4.1472e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.2456e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1044e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.6247e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.9821e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3206e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.6125e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.9089e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.4570e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1351e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.2900e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.7117e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.5462e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.0758e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.5197e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4321e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3154e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1596e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.3626e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.9559e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1991e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.9557e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.9705e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.3169e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.6588e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0119e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.5189e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.5777e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.9502e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.0211e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.9290e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.7372e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4254e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.3113e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -6.1417e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0667e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.6377e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNKNOWN
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNKNOWN
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.5819e-01
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.0156e-01
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.4986e-01
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.5390e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.3745e+00
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.4611e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.6744e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.6478e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.1681e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.7567e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.5172e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.1923e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.3294e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.7998e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System[HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.1711e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.1360e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.0443e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.5927e-02
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.3990e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.8869e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.9068e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.2503e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.6761e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.5802e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 5.3814e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.1078e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.6287e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.0213e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.4849e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.8802e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4806e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3788e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.2450e-03
# [HOOK] Detected NumericalStabi[HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.2872e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -9.0059e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 3.4229e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 2.1694e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.8967e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 6.4690e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System s[HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 4.0692e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 7.0008e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.0690e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 1.4232e-06
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: UNSTABLE
# [HOOK] Max eigenvalue real part: 8.1689e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.5505e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.9424e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.3518e-05
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.9439e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4974e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.4009e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.2735e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.1025e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -8.5490e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0910e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0466e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.3188e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -5.9330e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.8362e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.2023e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.0810e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -1.7037e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -7.2672e-04
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -3.7591e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -4.0174e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability results
# [HOOK] System stability: STABLE
# [HOOK] Max eigenvalue real part: -2.4745e-03
# [HOOK] Detected NumericalStabilitySolver - will capture stability res
# 2D Stability Scan complete. Total Time taken: 16.17124 seconds.

# %%
cost_grid, model_grid = compute_cost_grid(
    stability_results,
    phyto_esd=phyto_esd,
    zoo_esd=zoo_esd,
    obs_vec=obs_vec,
    bin_definitions=bin_defs,
    dim1_name=P1_NAME,
    dim2_name=P2_NAME,    avg_window=None,
    neg_tolerance=1e-6,
    clip_small_negatives=True,
    require_stable=False,
)

# %%
best = find_best_fit(cost_grid, model_grid, scan_results, P1_NAME, P2_NAME)

default = {
    'val1': get_default_from_setup(model_setup, P1_NAME),
    'val2': get_default_from_setup(model_setup, P2_NAME),
}

title_info = (f"{P1_NAME}={best['val1']:.4f}, "
              f"{P2_NAME}={best['val2']:.4f}, "
              f"cost={best['cost']:.3f}")

print(f"\n--- Best fit ---")
print(f"  {P1_LABEL}: {best['val1']:.5f}")
print(f"  {P2_LABEL}: {best['val2']:.5f}")
print(f"  Cost (NRMSRE): {best['cost']:.4f}")
# Out:
# --- Best fit ---
#   New nutrient flux F_N (mmol N m⁻² d⁻¹): 4.50123
#   Zoo half-saturation K_sZ (mmol N m⁻³): 0.48660
#   Cost (NRMSRE): 0.1645

# %%
best['model_vec']
# Out:
# array([0.48221042, 0.25715348, 0.20523644, 0.09032042, 0.03541745,
#        2.01959555, 0.28445354, 4.12002537])

# %%
from parscan_plots import summarize_best_fit
summarize_best_fit(
   model_vec=best['model_vec'],
   obs_vec=obs_vec,
   labels=labels,
   cost=best['cost'],
)
# Out:
# ===========================================================================
#  BEST-FIT SUMMARY  |  Overall cost (NRMSRE): 0.1645
# ===========================================================================
#      Component  Obs_Mean  Model_BestFit   Ratio  Rel_Error_%
#   Pico (<2 µm)   0.25445        0.48221 1.89514     89.51447
# Nano (2-20 µm)   0.14510        0.25715 1.77224     77.22409
# Micro (>20 µm)   0.20366        0.20524 1.00775      0.77541
#    Zoo >200 µm   0.06581        0.09032 1.37251     37.25136
#    Zoo >500 µm   0.03743        0.03542 0.94626     -5.37420
#            NO3   1.42750        2.01960 1.41478     41.47789
#             PP   0.32188        0.28445 0.88373    -11.62664
#         Export   2.71976        4.12003 1.51485     51.48495
# ===========================================================================
#         Component  Obs_Mean  Model_BestFit     Ratio  Rel_Error_%
# 0    Pico (<2 µm)  0.254445       0.482210  1.895145    89.514469
# 1  Nano (2-20 µm)  0.145101       0.257153  1.772241    77.224090
# 2  Micro (>20 µm)  0.203657       0.205236  1.007754     0.775414
# 3     Zoo >200 µm  0.065807       0.090320  1.372514    37.251361
# 4     Zoo >500 µm  0.037429       0.035417  0.946258    -5.374197
# 5             NO3  1.427499       2.019596  1.414779    41.477893
# 6              PP  0.321877       0.284454  0.883734   -11.626635
# 7          Export  2.719759       4.120025  1.514849    51.484947

# %%
from cariaco_ssm_setup import model_setup_slim
from parscan_utils import run_single_point

best_run = run_single_point(
    model, model_setup_slim,
    scan_params={P1_NAME: best['val1'], P2_NAME: best['val2']},
    fixed_overrides=forcing,
)

best_run['Nutrient__value'].plot.line(x='time')
plt.title(f'Nutrient  ({title_info})')
plt.show()

best_run['Phytoplankton__biomass'].plot.line(x='time')
plt.title('Phytoplankton')
plt.show()

best_run['Zooplankton__biomass'].plot.line(x='time')
plt.title('Zooplankton')
plt.show()

# %%
stable_mask = (stability_results['stability'] == 'stable').values

fig1 = plot_cost_heatmap(
    cost_grid, P1_VALUES, P2_VALUES, P1_LABEL, P2_LABEL, best,
    default=default,
    stable_mask=stable_mask,
)
plt.show()

fig3 = plot_model_vs_obs_boxplots(best['model_vec'], monthly_df, bin_defs,
                                  title_info=title_info)
plt.show()

# %%
from parscan_utils import compute_spectrum_cost_grid
from parscan_plots import plot_spectrum_composition_map


# New: spectrum-only secondary cost
spectrum_cost_grid = compute_spectrum_cost_grid(
    model_grid, obs_vec, bin_defs, type_filter='phyto')
spectrum_best = find_best_fit(spectrum_cost_grid, model_grid,
                              scan_results, P1_NAME, P2_NAME)

# RGB composition map with both best-fit markers
fig_spec = plot_spectrum_composition_map(
    model_grid, obs_vec, bin_defs,
    P1_VALUES, P2_VALUES, P1_LABEL, P2_LABEL,
    best=best,
    spectrum_best=spectrum_best,
    default=default,
)
plt.show()

# Quick numerical readout of the two minima
print(f"NRMSRE   best:  {P1_NAME}={best['val1']:.4f}, "
      f"{P2_NAME}={best['val2']:.4f}, cost={best['cost']:.4f}")
print(f"Spectrum best:  {P1_NAME}={spectrum_best['val1']:.4f}, "
      f"{P2_NAME}={spectrum_best['val2']:.4f}, "
      f"dist={spectrum_best['cost']:.4f}")
# Out:
# NRMSRE   best:  Inflow__FN=4.5012, Grazing__KsZ=0.4866, cost=0.1645
# Spectrum best:  Inflow__FN=8.0877, Grazing__KsZ=0.6994, dist=0.0215

# %%
from parscan_plots import summarize_best_fit
summarize_best_fit(
   model_vec=spectrum_best['model_vec'],
   obs_vec=obs_vec,
   labels=labels,
   cost=spectrum_best['cost'],
)
# Out:
# ===========================================================================
#  BEST-FIT SUMMARY  |  Overall cost (NRMSRE): 0.0167
# ===========================================================================
#      Component  Obs_Mean  Model_BestFit    Ratio  Rel_Error_%
#   Pico (<2 µm)   0.09698        1.54337 15.91466   1491.46572
# Nano (2-20 µm)   0.08512        1.22687 14.41418   1341.41814
# Micro (>20 µm)   0.19977        3.07141 15.37508   1437.50813
#    Zoo >200 µm   0.05938        0.38560  6.49402    549.40232
#    Zoo >500 µm   0.03302        0.13855  4.19560    319.55980
#            NO3   1.46705        3.87993  2.64471    164.47129
#             PP   0.43247        1.41292  3.26709    226.70889
#         Export   3.18267       19.73346  6.20029    520.02932
# ===========================================================================
#         Component  Obs_Mean  Model_BestFit      Ratio  Rel_Error_%
# 0    Pico (<2 µm)  0.096978       1.543372  15.914657  1491.465716
# 1  Nano (2-20 µm)  0.085116       1.226874  14.414181  1341.418135
# 2  Micro (>20 µm)  0.199765       3.071409  15.375081  1437.508130
# 3     Zoo >200 µm  0.059377       0.385596   6.494023   549.402316
# 4     Zoo >500 µm  0.033023       0.138550   4.195598   319.559798
# 5             NO3  1.467052       3.879931   2.644713   164.471292
# 6              PP  0.432470       1.412917   3.267089   226.708886
# 7          Export  3.182666      19.733462   6.200293   520.029321

# %%
# Where do both costs sit in their respective "good" regions?
nrmsre_thresh   = np.nanpercentile(cost_grid, 10)            # bottom decile
spectrum_thresh = np.nanpercentile(spectrum_cost_grid, 10)
joint_good      = (cost_grid <= nrmsre_thresh) & \
                  (spectrum_cost_grid <= spectrum_thresh)
print(f"Cells satisfying both bottom-decile thresholds: "
      f"{joint_good.sum()} / {joint_good.size}")
# Out:
# Cells satisfying both bottom-decile thresholds: 16 / 900

# %%
plt.scatter(cost_grid.ravel(), spectrum_cost_grid.ravel(),
            s=4, alpha=0.3)
plt.xlabel('NRMSRE cost'); plt.ylabel('Spectrum cost (rel-comp dist)')
plt.show()

# %%
summary = summarize_best_fit(
    model_vec=best['model_vec'],
    obs_vec=obs_vec,
    labels=labels,
    cost=best['cost'],
)
# Out:
# ===========================================================================
#  BEST-FIT SUMMARY  |  Overall cost (NRMSRE): 0.2978
# ===========================================================================
#      Component  Obs_Mean  Model_BestFit   Ratio  Rel_Error_%
#   Pico (<2 µm)   0.09698        0.34612 3.56911    256.91069
# Nano (2-20 µm)   0.08512        0.17732 2.08334    108.33359
# Micro (>20 µm)   0.19977        0.17603 0.88118    -11.88173
#    Zoo >200 µm   0.05938        0.06380 1.07452      7.45210
#    Zoo >500 µm   0.03302        0.01288 0.39011    -60.98913
#            NO3   1.46705        1.49472 1.01886      1.88588
#             PP   0.43247        0.19106 0.44178    -55.82190
#         Export   3.18267        2.67977 0.84199    -15.80117
# ===========================================================================

# %%
cell = stability_results.sel({P1_NAME: best['val1'], P2_NAME: best['val2']},
                             method='nearest').isel(time=-1)

# Volumetric rates [mmol N m-3 d-1]
FN_per_de  = float(cell['Inflow__FN']) / float(cell['Inflow__de'])
export_vol = float(cell['DetritusSink__sinking_value'])
fish_P     = float(cell['FishGrazing__fish_graze_phyto_value'].sum('phyto'))
fish_Z     = float(cell['FishGrazing__fish_graze_zoo_value'].sum('zoo'))
zoo_closure_export = float(cell['ZooMortality__mortality_value'].sum('zoo')) \
                   - float(cell['ZooMortality__mortality_to_D_value'])

lhs = FN_per_de
rhs = export_vol + fish_P + fish_Z + zoo_closure_export
print(f"F_N/d_e     = {lhs:.6f}")
print(f"Losses sum  = {rhs:.6f}")
print(f"  sinking       : {export_vol:.6f}")
print(f"  fish on P     : {fish_P:.6f}")
print(f"  fish on Z     : {fish_Z:.6f}")
print(f"  zoo closure   : {zoo_closure_export:.6f}")
print(f"Residual    = {lhs-rhs:.2e}")

# And the f-ratio interpretation:
pp_total = float(cell['Growth__uptake_value'].sum('phyto'))
print(f"\nTotal PP    = {pp_total:.6f}")
print(f"New PP      = {FN_per_de:.6f}  (≡ F_N/d_e)")
print(f"Regen PP    = {pp_total - FN_per_de:.6f}")
print(f"f-ratio     = {FN_per_de / pp_total:.3f}")
# Out:
# F_N/d_e     = 0.063638
# Losses sum  = 0.063638
#   sinking       : 0.058797
#   fish on P     : 0.000199
#   fish on Z     : 0.000153
#   zoo closure   : 0.004489
# Residual    = -4.91e-15
#
# Total PP    = 0.191057
# New PP      = 0.063638  (≡ F_N/d_e)
# Regen PP    = 0.127419
# f-ratio     = 0.333
